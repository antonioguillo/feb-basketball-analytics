# %% [markdown]
# # Análisis de Baloncesto FEB

# %%
import sys
sys.path.insert(0, '.')

import pandas as pd
import numpy as np
from notebooks.analysis import load_data, top_scorers, calculate_team_stats

print('Libraries loaded successfully')

# %%
df = load_data('data/processed/sample_games.parquet')
print(f'Dataset loaded: {len(df)} rows')
print(f'Columns: {list(df.columns)}')

# %% [markdown]
# ## Top Scorers

# %%
scorers = top_scorers(df, n=10)
print(scorers)

# %% [markdown]
# ## Team Statistics

# %%
team_stats = calculate_team_stats(df)
print(team_stats.head())
